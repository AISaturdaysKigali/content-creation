# %% [markdown]
# ### Coding Exercise ?: Exercise title
#
# The below information is very **IMPORTANT** so as not to break the [AI6kigali ci](https://github.com/AISaturdaysKigali/ai6kigali-ci)
#
# `"?"` must match the subsection number (if it falls under a subsection). E.g. 1.1, 1.2, etc. or match the section number (if it falls under a subsection). E.g. 1, 2, etc
#
# **Exercises must follow a 3-cell structure**:
#
# - Markdown: Title and any other texts or images (like this cell), followed by,
# - Code: Exercise code, followed by,
# - Code: Solution code
#
# **Editor guideline for exercise solution code formatting**:
#
# - The presence of `# to_remove solution` in the first line of solution block
# - The absence of the fenced `(#####)` block that raises a NotImplementedError
# - Valid code replacing all ellipses `(...)`
# - Code that uses or depends on the completed function/lines is uncommented
# - Plotting code is indented under a with plt.xkcd(): context manager.
# - Using **SAME SEED** such that student should be able to replicate sample results **exactly**.
# - **All other comments and code should be identical**
#
# See example below:

# %%
def square(x):
  """
  A function that squares a given number.

  Args:
    x: int or float
      An integer or float number

  Returns:
    y: int or float
      Square of input x.
  """
  #################################################
  ## TODO for students: fill in the missing code
  ## from the first expression
  raise NotImplementedError("Student exercise: say what they should have done")
  #################################################
  y = ...

  return y


# integer to square
x = 8

# Uncomment below to check your function!
# y = square(x)
# assert y == 64
# print("Correct")

# %%
# to_remove solution
def square(x):
  """
  A function that squares a given number.

  Args:
    x: int or float
      An integer or float number

  Returns:
    y: int or float
      Square of input x.
  """
  y = x ** 2

  return y


# integer to square
x = 8

# Uncomment below to check your function!
y = square(x)
assert y == 64
print("Correct")
